# %% [markdown]
# <a href="https://colab.research.google.com/github/nandini-choubey/SD_Kumari-Nandini-Choubey_0132/blob/main/Math%2C_Random%2C_Datetime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
num =25
print(math.sqrt(num))
# Out:
# 5.0

# %%
print(math.pow(2,5))
# Out:
# 32.0

# %%
print(math.factorial(5))
# Out:
# 120

# %%
print(math.ceil(4.2))
# Out:
# 5

# %%
print(math.floor(4.9))
# Out:
# 4

# %%
print(abs(-50))
# Out:
# 50

# %%
print(math.gcd(24,36))
# Out:
# 12

# %%
print(math.lcm(12,18))
# Out:
# 36

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
print(math.sin(math.radians(90)))
# Out:
# 1.0

# %%
print(math.cos(math.radians(90)))
# Out:
# 6.123233995736766e-17

# %%
print(math.tan(math.radians(45)))
# Out:
# 0.9999999999999999

# %%
print(math.log10(100))
# Out:
# 2.0

# %%
print(math.log(10))
# Out:
# 2.302585092994046

# %%
import random

# %%
print(random.randint(1,100))
# Out:
# 36

# %%
print(random.random())
# Out:
# 0.23824861543584552

# %%
print(random.randrange(1,100))
# Out:
# 71

# %%
fruits = ["apple","Hello","Mango"]
print(random.choice(fruits))
# Out:
# Mango

# %%
numbers = [1,2,3,4,5]
random.shuffle(numbers)
print(numbers)
# Out:
# [4, 2, 3, 1, 5]

# %%
print(random.uniform(1,10))
# Out:
# 7.498860963027047

# %%
print(random.choice([True,False]))
# Out:
# True

# %%
otp =random.randint(1000,9999)
print("OTP =",otp)
# Out:
# OTP = 7378

# %%
import datetime

# %%
print(datetime.datetime.now())
# Out:
# 2026-07-20 06:24:56.086699

# %%
print(datetime.date.today())
# Out:
# 2026-07-20

# %%
print(datetime.datetime.now().time())
# Out:
# 06:28:45.167988

# %%
print(datetime.datetime.now().year)
# Out:
# 2026

# %%
print(datetime.datetime.now().month)
# Out:
# 7

# %%
print(datetime.datetime.now().day)
# Out:
# 20

# %%
print(datetime.datetime.now().hour)
# Out:
# 6

# %%
print(datetime.datetime.now().minute)
# Out:
# 35

# %%
print(datetime.datetime.now().second)
# Out:
# 12

# %%
print(datetime.datetime.now().microsecond)
# Out:
# 312325

# %%
#Custom
d = datetime.date(2026,7,19)
print(d)
# Out:
# 2026-07-19

# %%
t= datetime.time(10,30,45)
print(t)
# Out:
# 10:30:45

# %%
date1 =datetime.date(2026,7,19)
date2 =datetime.date(2026,8,19)
print(date2-date1)
# Out:
# 31 days, 0:00:00

# %%
today = datetime.datetime.now()
print(today.strftime("%d-%m-%Y"))
# Out:
# 20-07-2026

# %%
now=datetime.datetime.now()
print(now.strftime("%H:%M:%S"))
# Out:
# 06:50:05

# %%
today = datetime.datetime.now()
print(today.strftime("%A"))
# Out:
# Monday

# %%
today =datetime.datetime.now()
print(today.strftime("%B"))
# Out:
# July

# %%
import time
for i in range(10) :
  current_time = time.strftime("%H:%M:%S")
  print(current_time)
  time.sleep(1)

  print("\nclock stopped.")
# Out:
# 08:28:43
#
# clock stopped.
# 08:28:44
#
# clock stopped.
# 08:28:45
#
# clock stopped.
# 08:28:46
#
# clock stopped.
# 08:28:47
#
# clock stopped.
# 08:28:48
#
# clock stopped.
# 08:28:49
#
# clock stopped.
# 08:28:50
#
# clock stopped.
# 08:28:51
#
# clock stopped.
# 08:28:52
#
# clock stopped.

# %%
import time
from IPython.display import clear_output
from datetime import datetime

while True:
  clear_output(wait=True)

  current_time = datetime.now().strftime("%I:%M:%S %p")

  print("   Digital Clock")
  print(current_time)

  time.sleep(1)
# Out:
#    Digital Clock
# 08:48:13 AM
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9183/1225524387.py in <cell line: 0>()
#      11   print(current_time)
#      12
# ---> 13   time.sleep(1)
#
# KeyboardInterrupt:

# %%
import time
from IPython.display import clear_output
from datetime import datetime
from zoneinfo import ZoneInfo

while True:
  clear_output(wait=True)

  ist_time = datetime.now(ZoneInfo("Asia/Kolkata"))

  print("   Digital Clock")
  print("Date :",ist_time.strftime("%d-%m-%Y"))
  print("Time :",ist_time.strftime("%I:%M:%S %p"))
  print("Zone :","Indian Standard Time (IST")
  print("Day :",ist_time.strftime("%A"))

  time.sleep(1)
# Out:
#    Digital Clock
# Date : 20-07-2026
# Time : 02:52:21 PM
# Zone : Indian Standard Time (IST
# Day : Monday
