# %% [markdown]
# <a href="https://colab.research.google.com/github/nandini-choubey/SD_Kumari-Nandini-Choubey_0132/blob/main/stack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
stack = []

# Operations
stack.append(12)
stack.pop()
stack.append(13)
stack.append(11)
stack.append(8)
stack.append(15)
stack.pop()
stack.pop()
stack.append(17)
stack.pop()
stack.pop()


if stack:
    print("Top Element =", stack[-1])
else:
    print("Stack is empty")
# Out:
# Top Element = 13
