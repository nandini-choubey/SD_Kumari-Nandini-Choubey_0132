# %% [markdown]
# <a href="https://colab.research.google.com/github/nandini-choubey/SD_Kumari-Nandini-Choubey_0132/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l=[1,345,45,"sudh",5+7j,True ,345.456]

# %%
l[5].real
# Out:
# 1

# %%
l[::2]
# Out:
# [1, 45, (5+7j), 345.456]

# %%
l[0]
# Out:
# 1

# %%
l[1]
# Out:
# 345

# %%
l[0:5:2]
# Out:
# [1, 45, (5+7j)]

# %%
l[0:5:4]
# Out:
# [1, (5+7j)]

# %%
l[-1]
# Out:
# 345.456

# %%
l[-1:-5:-2]
# Out:
# [345.456, (5+7j)]

# %%
l[1:6:-2]
# Out:
# []

# %%
l
# Out:
# [1, 345, 45, 'sudh', (5+7j), True, 345.456, '245']

# %%
l[-1::-6]
# Out:
# ['245', 345]

# %%
l.append(10)

# %%
l.pop()
# Out:
# 10

# %%
l.delete(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_542/2547569950.py in <cell line: 0>()
# ----> 1 l.delete(4)
#
# AttributeError: 'list' object has no attribute 'delete'

# %%
str ={"NANDINI CHOUBEY"}

# %%
L+str
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_542/2292560291.py in <cell line: 0>()
# ----> 1 L+str
#
# NameError: name 'L' is not defined

# %%
list(str)+l
# Out:
# ['NANDINI CHOUBEY', 1, 345, 45, 'sudh', (5+7j), True, 345.456, '245']

# %%
l1 = [1,345,7,2]

# %%
l1.append(4)

# %%
l1.pop()
# Out:
# 4

# %%
l[3][0]
# Out:
# 's'

# %%
l[3][0:2]
# Out:
# 'su'

# %%
l[3][0:3]
# Out:
# 'sud'

# %%
l
# Out:
# [1, 345, 25, 25, (5+7j), True, 345.456]

# %%
str(l[5])[0:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_542/32271797.py in <cell line: 0>()
# ----> 1 str(l[5])[0:2]
#
# TypeError: 'set' object is not callable

# %%
l[5][0:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_542/3272358523.py in <cell line: 0>()
# ----> 1 l[5][0:2]
#
# TypeError: 'bool' object is not subscriptable

# %%
str(l[5])[0:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_542/32271797.py in <cell line: 0>()
# ----> 1 str(l[5])[0:2]
#
# TypeError: 'set' object is not callable

# %%
l.insert(2,25)

# %%
l
# Out:
# [1, 345, 25, 25, (5+7j), True, 345.456]

# %%
l.pop(4)
# Out:
# 'sudh'

# %%
l
# Out:
# [1, 345, 25, 25, (5+7j), True, 345.456]

# %%
name=input("enter your name:")
# Out:
# enter your name:Nandini

# %%
print("Name:",name)
# Out:
# Name: Nandini

# %%
age=int(input("enter the age:"))
# Out:
# enter the age:19

# %%
print("age:" ,age)
# Out:
# age: 19

# %%
x="10"

# %%
y=int(x)

# %%
print(y)
# Out:
# 10

# %%
x="3.14"

# %%
y=float(x)

# %%
print(y)
# Out:
# 3.14

# %%
A=25

# %%
b=str(A)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_542/397070767.py in <cell line: 0>()
# ----> 1 b=str(A)
#
# TypeError: 'set' object is not callable

# %%
C=(1,2,3)

# %%
d=list(C)

# %%
print(d)
# Out:
# [1, 2, 3]

# %%
e=[1,2,3]

# %%
f=tuple(e)

# %%
print(f)
# Out:
# (1, 2, 3)

# %%
g=[1,2,3,2]

# %%
h=set(g)

# %%
print(h)
# Out:
# {1, 2, 3}
