# %% [markdown]
# <a href="https://colab.research.google.com/github/nandini-choubey/SD_Kumari-Nandini-Choubey_0132/blob/main/list_%2C_tuple%2C_dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l=[1,345,25,True,(5+7j),678.89,"nandini"]

# %%
l[4].real
# Out:
# 5.0

# %%
l[0:6:2]
# Out:
# (1, 25, (5+7j))

# %%
type[l]
# Out:
# type[1, 345, 25, True, (5+7j), 678.89, 'nandini']

# %%
l[1]
# Out:
# 345

# %%
l[3]
# Out:
# True

# %%
l[-1:-7:-2]
# Out:
# ('nandini', (5+7j), 25)

# %%
l[::-1]
# Out:
# ('nandini', 678.89, (5+7j), True, 25, 345, 1)

# %%
s="maritimeexpertise"

# %%
l + s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_903/696898255.py in <cell line: 0>()
# ----> 1 l + s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s) + l
# Out:
# ['m',
#  'a',
#  'r',
#  'i',
#  't',
#  'i',
#  'm',
#  'e',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  't',
#  'i',
#  's',
#  'e',
#  1,
#  345,
#  25,
#  True,
#  (5+7j),
#  678.89,
#  'nandini']

# %%
list(s) + l

# %%
type(l[6])
# Out:
# str

# %%
l[6][0:2]
# Out:
# 'na'

# %%
l1=[3,4,4]

# %%
l1 + l
# Out:
# [3, 4, 4, 1, 345, 25, True, (5+7j), 678.89, 'nandini']

# %%
l1*3
# Out:
# [3, 4, 4, 3, 4, 4, 3, 4, 4]

# %%
l
# Out:
# [1, 345, 25, True, (5+7j), 678.89, 'nandini']

# %%
len(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_903/2982808344.py in <cell line: 0>()
# ----> 1 len(1)
#
# TypeError: object of type 'int' has no len()

# %%
l.append(1)

# %%
l
# Out:
# [1, 345, 25, True, (5+7j), 678.89, 'nandini', 1, 1]

# %%
s
# Out:
# 'maritimeexpertise'

# %%
l
# Out:
# [1, 345, 25, True, (5+7j), 678.89, 'nandini', 1, 1]

# %%
l.append(s)

# %%
l
# Out:
# [1,
#  345,
#  25,
#  True,
#  (5+7j),
#  678.89,
#  'nandini',
#  1,
#  1,
#  'maritimeexpertise',
#  'maritimeexpertise']

# %%
l.append(l1)

# %%
l[-1][1]
# Out:
# 4

# %%
l.extend("nandini")

# %%
l
# Out:
# [1,
#  345,
#  25,
#  True,
#  (5+7j),
#  678.89,
#  'nandini',
#  1,
#  1,
#  'maritimeexpertise',
#  'maritimeexpertise',
#  [3, 4, 4],
#  [3, 4, 4],
#  'n',
#  'a',
#  'n',
#  'd',
#  'i',
#  'n',
#  'i',
#  'n',
#  'a',
#  'n',
#  'd',
#  'i',
#  'n',
#  'i']

# %%
l.extend([3,4,5])

# %%
l
# Out:
# [1,
#  345,
#  25,
#  True,
#  (5+7j),
#  678.89,
#  'nandini',
#  1,
#  1,
#  'maritimeexpertise',
#  'maritimeexpertise',
#  [3, 4, 4],
#  [3, 4, 4],
#  'n',
#  'a',
#  'n',
#  'd',
#  'i',
#  'n',
#  'i',
#  'n',
#  'a',
#  'n',
#  'd',
#  'i',
#  'n',
#  'i',
#  3,
#  4,
#  5,
#  3,
#  4,
#  5]

# %%
l1
# Out:
# [3, 4, 4]

# %%
l1.insert(1,"nandini")

# %%
l1
# Out:
# [3, 'nandini', 'nandini', 4, 4]

# %%
l1.insert(1,"boy")

# %%
l1
# Out:
# [3, 'boy', 'boy', 'nandini', 'nandini', 4, 4]

# %%
l1.pop()
# Out:
# 'nandini'

# %%
l1
# Out:
# [3, 'boy', 'boy', 'nandini']

# %%
l1.pop(0)
# Out:
# 3

# %%
l1.remove(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_903/4082324864.py in <cell line: 0>()
# ----> 1 l1.remove(3)
#
# ValueError: list.remove(x): x not in list

# %%
l1
# Out:
# ['boy', 'boy']

# %%
l1.reverse()

# %%
l1
# Out:
# ['boy', 'boy']

# %%
l2=[2.3,5,89.67,47,67,23,25,78,34]

# %%
l2.sort()

# %%
l2
# Out:
# [2.3, 5, 23, 25, 34, 47, 67, 78, 89.67]

# %%
l3=["ram","shyam","rahul"]

# %%
l3.sort()

# %%
l3
# Out:
# ['rahul', 'ram', 'shyam']

# %%
l4=[1,2,"sudh"]

# %%
l4.count("sudh")
# Out:
# 1

# %%
l4.index(2)
# Out:
# 1

# %%
s
# Out:
# 'maritimeexpertise'

# %%
s.replace('i','a')
# Out:
# 'maratameexpertase'

# %%
t=(2,3,4,5,"sudh",25.56,False,(456+456j),[3,4,5])

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 9

# %%
t[0]
# Out:
# 2

# %%
t[-1]
# Out:
# [3, 4, 5]

# %%
t.append(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_903/3848969903.py in <cell line: 0>()
# ----> 1 t.append(6)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t.remove(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_903/1350428641.py in <cell line: 0>()
# ----> 1 t.remove(4)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
t.insert(56)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_903/364429492.py in <cell line: 0>()
# ----> 1 t.insert(56)
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
t.pop(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_903/2035704701.py in <cell line: 0>()
# ----> 1 t.pop(4)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
t*3
# Out:
# (2,
#  3,
#  4,
#  5,
#  'sudh',
#  25.56,
#  False,
#  (456+456j),
#  [3, 4, 5],
#  2,
#  3,
#  4,
#  5,
#  'sudh',
#  25.56,
#  False,
#  (456+456j),
#  [3, 4, 5],
#  2,
#  3,
#  4,
#  5,
#  'sudh',
#  25.56,
#  False,
#  (456+456j),
#  [3, 4, 5])

# %%
s1={}

# %%
type(s1)
# Out:
# dict

# %%
s2= {2,3,4,5,6,78}

# %%
type(s2)
# Out:
# set

# %%
s3= {345,356,678,"SUDH",45+45j,456.678,(3,4,5)}

# %%
s3
# Out:
# {(3, 4, 5), (45+45j), 345, 356, 456.678, 678, 'SUDH'}

# %%
s4= {2,3,4,5,67,7,8,89,6,4,3,3,2,3,4,5,6,7,8,9,'SUDH','sudh'}

# %%
s4
# Out:
# {2, 3, 4, 5, 6, 67, 7, 8, 89, 9, 'SUDH', 'sudh'}

# %%
l6= [2,3,4,5,67,7,8,89,6,4,3,3,2,3,4,5,6,7,8,9,'SUDH','sudh']

# %%
l6
# Out:
# [2, 3, 4, 5, 67, 7, 8, 89, 6, 4, 3, 3, 2, 3, 4, 5, 6, 7, 8, 9, 'SUDH', 'sudh']

# %%
l6=list(set(l6))

# %%
l6
# Out:
# [2, 3, 67, 4, 5, 7, 8, 6, 9, 'SUDH', 'sudh', 89]

# %%
s5= {234,45,23,12,567,45,2,789,234,"abc",456,342,23}

# %%
s5
# Out:
# {12, 2, 23, 234, 342, 45, 456, 567, 789, 'abc'}

# %%
s5.add(4)

# %%
s5
# Out:
# {12, 2, 23, 234, 342, 4, 45, 456, 567, 789, 'abc'}

# %%
s5.remove(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_903/3651126432.py in <cell line: 0>()
# ----> 1 s5.remove(2)
#
# KeyError: 2

# %%
s5.remove(234)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_903/3762271536.py in <cell line: 0>()
# ----> 1 s5.remove(234)
#
# KeyError: 234

# %%
s5
# Out:
# {12, 23, 342, 4, 45, 456, 567, 789, 'abc'}

# %%
d ={}

# %%
type(d)
# Out:
# dict

# %%
d1 = {'key': 'value'}

# %%
d1
# Out:
# {'key': 'value'}

# %%
d2 = {'name' :"nandini","email": "ss@gmail.com","number":334564}

# %%
d2
# Out:
# {'name': 'nandini', 'email': 'ss@gmail.com', 'number': 334564}

# %%
d3= {234 : "sudh",'_wer' : "kumar",True:23455}

# %%
d3[234]
# Out:
# 'sudh'

# %%
d3[True]
# Out:
# 23455

# %%
d3[1]
# Out:
# 23455

# %%
d4 = {'name':"sudh",'mail_id':"ss@gmail.com",'name':"sudhanshu"}

# %%
d4['name']
# Out:
# 'sudhanshu'
