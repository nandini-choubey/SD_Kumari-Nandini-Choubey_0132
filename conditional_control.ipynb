# %% [markdown]
# <a href="https://colab.research.google.com/github/nandini-choubey/SD_Kumari-Nandini-Choubey_0132/blob/main/conditional_control.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=10

# %%
if x > 5:
  print("x is greater than 5:")
# Out:
# x is greater than 5:

# %%
a=3

# %%
if a%2==0:
 print("a is even:")
else :
  print("a is odd")
# Out:
# a is odd

# %%
l=[1,2,3,True]

# %%
str(l[3])[0:2]
# Out:
# 'Tr'

# %%
name= input("enter your name:")
course=input("enter your course")
rollno =int(input("enter your roll no"))
Branch= input("enter your branch ")
marks= int(input("enter your marks"))
subject= input("enter your subject ")
# Out:
# enter your name:Kumari Nandini Choubey
# enter your courseBtech
# enter your roll no2501220100132
# enter your branch CSE
# enter your marks890
# enter your subject maths ,Data structure, python programming, architecture ,discrete structure, human Values

# %%
Maths=int(input("enter your maths marks"))
humanvalues= int(input("enter your human value marks"))
DataStructure= int(input("enter your data sturucture marks"))
python= int(input("enter your python marks"))
artichecture=int(input("enter your artichecture marks"))
discrteStructure=int(input("enter your disrete structure"))
# Out:
# enter your maths marks89
# enter your human value marks56
# enter your data sturucture marks56
# enter your python marks56
# enter your artichecture marks86
# enter your disrete structure78

# %%
add = Maths+ DataStructure+ python+ artichecture+ discrteStructure+ humanvalues

# %%
p=add/6

# %%
print(p)
# Out:
# 70.16666666666667
