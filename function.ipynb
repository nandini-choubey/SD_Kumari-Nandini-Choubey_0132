# %% [markdown]
# <a href="https://colab.research.google.com/github/nandini-choubey/SD_Kumari-Nandini-Choubey_0132/blob/main/function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=2
b=4
sum= a+b

# %%
def test():
 pass

# %%
def test1():
  print("this is my very very first function")

# %%
test1()
# Out:
# this is my very very first function

# %%
test1() + "sudh"
# Out:
# this is my very very first function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_746/3118336650.py in <cell line: 0>()
# ----> 1 test1() + "sudh"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
def test2():
  return "this is my very first return"

# %%
test2()
# Out:
# 'this is my very first return'

# %%
test2()+"sudh"
# Out:
# 'this is my very first returnsudh'

# %%
def test3() :
  return "sudh" ,23,456.67,[1,2,3,3]

# %%
test3()
# Out:
# ('sudh', 23, 456.67, [1, 2, 3, 3])

# %%
a,b,c,d= test3()

# %%
a
# Out:
# 'sudh'

# %%
type(test3)
# Out:
# function

# %%
b
# Out:
# 23

# %%
c
# Out:
# 456.67

# %%
d
# Out:
# [1, 2, 3, 3]

# %%
type(test3)
# Out:
# function

# %%
a=1
b=4

# %%
a  ,b =1,4

# %%
def add():
  a=5+6/7
  return a

# %%
add()
# Out:
# 5.857142857142857

# %%
def test5(a,b,c):
  d =a+b/c
  return d

# %%
test5(4,5,6.78)
# Out:
# 4.737463126843657

# %%
test5(2,5,8)
# Out:
# 2.625

# %%
def test6(a,b):
  return a+b

# %%
test6(3,4)
# Out:
# 7

# %%
test6("hello" ,"world")
# Out:
# 'helloworld'

# %%
test6((2,3,4), (9,8,7))
# Out:
# (2, 3, 4, 9, 8, 7)

# %%
test6(["hellow", 67.88],[567.89,True])
# Out:
# ['hellow', 67.88, 567.89, True]

# %%
def test11(*args):
  return args + (1,2,3,4)

# %%
type(test11())
# Out:
# tuple

# %%
test11(1,2,3)
# Out:
# (1, 2, 3, 1, 2, 3, 4)

# %%
def test17(*kwargs) :
  return kwargs + (1,2,3,4)

# %%
type(test17())
# Out:
# tuple

# %%
test17(1,2,3)
# Out:
# (1, 2, 3, 1, 2, 3, 4)

# %%
test17(1,2,3,"sudh","kumar",[1,2,3,4,5])
# Out:
# (1, 2, 3, 'sudh', 'kumar', [1, 2, 3, 4, 5], 1, 2, 3, 4)

# %%
def test12(*sudh):
  return sudh

# %%
test12(1,2,3,4)
# Out:
# (1, 2, 3, 4)

# %%
def test13(*args,a):
  return args,a

# %%
test13(1,2,3,4,a=23)
# Out:
# ((1, 2, 3, 4), 23)

# %%
def test14(c,d,a=23,b=1):
  return a,b,c,d

# %%
test14()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_746/3076521518.py in <cell line: 0>()
# ----> 1 test14()
#
# TypeError: test14() missing 2 required positional arguments: 'c' and 'd'

# %%
test14(c,d)
# Out:
# (23, 1, 456.67, [1, 2, 3, 3])

# %%
test14(3,4)
# Out:
# (23, 1, 3, 4)

# %%
test14(2,5,a=2343)
# Out:
# (2343, 1, 2, 5)

# %%
def test15(**kwargs):
    return kwargs

# %%
test15()
# Out:
# {}

# %%
type(test15())
# Out:
# dict

# %%
test15(a=[1,2,3,4],b="sudh",c=23.45)
# Out:
# {'a': [1, 2, 3, 4], 'b': 'sudh', 'c': 23.45}

# %%
def add(a,b) :
  return a+b
  def sub(a,b) :
    return a-b

# %%
def calc(a,b,p):
  if (p=="+"):

    print(a+b)
  elif(p=="-"):
    print(a-b)
  elif(p=="*"):
    print(a*b)
  elif(p=="/"):
    print(a/b)
  return "done"
n1=int(input("enter n1"))
n2=int(input("enter n2"))
op=input("enter operator")
calc(n1,n2,op)
# Out:
# enter n112
# enter n234
# enter operator+,-,*,/
# 'done'
