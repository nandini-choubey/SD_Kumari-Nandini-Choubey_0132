# %% [markdown]
# <a href="https://colab.research.google.com/github/nandini-choubey/SD_Kumari-Nandini-Choubey_0132/blob/main/Loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l=[1,2,3,4,5,"sudh","kumar",456,58.678,"abc"]

# %%
l1_num =[]
l2_str = []
for i in l:
    if type(i) == int or type(i) == float:
        l1_num.append(i)
    else:
        l2_str.append(i)

# %%
list= [1,3,4,5,"sudh",True, 678.576,[2,3,4]]

# %%
l3_num =[]
l4_str = []
l5_float = []
l6_bool =[]
for i in list:
  if type(i) == int:
    l3_num.append(i)
  elif type(i) == str:
    l4_str.append(i)
  elif type(i) == float:
    l5_float.append(i)
  else:
    l6_bool.append(i)

# %%
num =int(input("enter a num"))
# Out:
# enter a num567

# %%
if temp == reverse:
  print(temp,"is a pallindrome no:")
else:
  print(temp,"is not a pallindrome no:")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2001/627467874.py in <cell line: 0>()
# ----> 1 if temp == reverse:
#       2   print(temp,"is a pallindrome no:")
#       3 else:
#       4   print(temp,"is not a pallindrome no:")
#       5
#
# NameError: name 'temp' is not defined

# %%
num=int(input("enter a number"))
temp=num
reverse=0
while num>0:
  digit=num%10
  reverse=reverse*10+digit
  num=num//10
if temp==reverse:
  print(temp,"is a pallindrome no:")
else:
  print(temp,"is not a pallindrome no:")
# Out:
# enter a number456
# 456 is not a pallindrome no:

# %%
l9=[2,3,79,5,78,6,7,78,78,6,5,44]

# %%
total =0
for i in l9 :
 total = total + i

# %%
print(total)
# Out:
# 391

# %%
odd = 0
for i in l9:
  if i%2!=0:
     odd =odd + i

# %%
print(odd)
# Out:
# 99

# %%
dict1 ={'a':"akshat",'b':'bhuvan','c': 'chandan'}

keys = []
values = []
for item in dict1.items():
    keys.append(item[0]),values.append(item[1])

print("keys :",keys)
print("values :",values)
# Out:
# keys : ['a', 'b', 'c']
# values : ['akshat', 'bhuvan', 'chandan']
