# %% [markdown]
# <a href="https://colab.research.google.com/github/nandini-choubey/SD_Kumari-Nandini-Choubey_0132/blob/main/list_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l=[1,3,9]

# %%
l1=[]
for i in l:
 l1.append(i**2)

# %%
l1
# Out:
# [1, 9, 81]

# %%
[i**2 for i in l]
# Out:
# [1, 9, 81]

# %%
[i for i in l if i% 2==0 ]
# Out:
# []

# %%
l1=["sudh","rahul","ram"]

# %%
[i.upper() for i in l1]
# Out:
# ['SUDH', 'RAHUL', 'RAM']

# %%
l
# Out:
# [1, 3, 9]

# %%
list(i**2 for i in l)
# Out:
# [1, 9, 81]

# %%
d = {"key1" : 1 , "key" : 2,"key3": 3, "key 4" : 4}

# %%
{k:v**2 for k,v in d.items()}
# Out:
# {'key1': 1, 'key': 4, 'key3': 9, 'key 4': 16}

# %%
d.items()
# Out:
# dict_items([('key1', 1), ('key', 2), ('key3', 3), ('key 4', 4)])

# %%
d
# Out:
# {'key1': 1, 'key': 2, 'key3': 3, 'key 4': 4}

# %%
{k : v for k,v in d.items() if v>1}
# Out:
# {'key': 2, 'key3': 3, 'key 4': 4}
